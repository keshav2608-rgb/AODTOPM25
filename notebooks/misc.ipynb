# %%
import os

folder_path = r"C:\Users\kesha\OneDrive - dtu.ac.in\Desktop\aodtopm25\data\raw\merra"

count = 0
for item in os.listdir(folder_path):
    if os.path.isfile(os.path.join(folder_path, item)):
        count += 1

print("Number of files:", count)
# Out:
# Number of files: 730

# %%
import os

folder_path = r"C:\Users\kesha\OneDrive - dtu.ac.in\Desktop\aodtopm25\data\raw\insat"   
file_count = 0

for root, dirs, files in os.walk(folder_path):
    file_count += len(files)

print("Total number of files:", file_count)
# Out:
# Total number of files: 4745
